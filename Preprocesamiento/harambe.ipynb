A\' b\'RT @SamTulipane: 3 years ago this sweet prince was murdered. Legends never die. #RIPHarambe #Harambe https://t.co/LLdF55aWGe\' b\'RT @BasedBeefy: I miss you so fucken much #RIPHarambe https://t.co/LWvEexqImA\' b"RT @xTemq: Good clip? Lol. Sorry for my harambe noises. Also it\'s the anniversary of his death. #RIPHarambe https://t.co/mFu4XqohR1" b\'RT @HunterKirkpatr2: Today marks 3 years! #RipHarambe https://t.co/wYwmPjlY2C\' b\'As of yesterday, we lost a wonderful member to the Ohio community three years ago. The man we lost was none other t\\xe2\\x80\\xa6 https://t.co/bW1uakASUP\' b\'#RIPHarambe https://t.co/JndpHCjTTV\' b\'RT @CincyProblems: Three years ago today, Cincinnati lost a legend. \\xf0\\x9f\\xa6\\x8d #RIPHarambe https://t.co/In7Jcb7L5A\' b\'RT @BasedBeefy: I miss you so fucken much #RIPHarambe https://t.co/LWvEexqImA\' b\'RT @CincyProblems: Three years ago today, Cincinnati lost a legend. \\xf0\\x9f\\xa6\\x8d #RIPHarambe https://t.co/In7Jcb7L5A\' b\'Never forget #RIPHarambe https://t.co/eCnxNi1t2A\' b\'RT @CincyProblems: Three years ago today, Cincinnati lost a legend. \\xf0\\x9f\\xa6\\x8d #RIPHarambe https://t.co/In7Jcb7L5A\' b"No one know who you are \'till your dead. #RIPHarambe" b\'RT @BasedBeefy: I miss you so fucken much #RIPHarambe https://t.co/LWvEexqImA\' b\'RT @sense_patriot: \\xf0\\x9f\\x87\\xba\\xf0\\x9f\\x87\\xb8Daily #MAGA Train #103\\xf0\\x9f\\x87\\xba\\xf0\\x9f\\x87\\xb8\\nRetweet and follow to unite patriots!\\n@KamyMAGA\\n@IssyMartinez\\n@DwayneRay9\\n@DaleP4656\\n@USA1stW\\xe2\\x80\\xa6\' b\'RT @OfficialJoelF: Brands in 2019 \\xf0\\x9f\\x98\\x82\\xf0\\x9f\\x98\\x82 thanks! @RoyalCaribbean #RIPHarambe https://t.co/4uwlVYZMTu\' b\'RT @Dan_Nagano3193: You will always be with us in our hearts \\xf0\\x9f\\x92\\x94 #RIPHarambe ht ...

# %%
import re
import nltk

from nltk.corpus import stopwords
from nltk import word_tokenize

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

stopwords_en = stopwords.words('english')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\juane\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\juane\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\juane\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
import contractions
sentence = contractions.fix(sentence)
sentence = sentence.lower()
sentence = re.sub(r'_','', sentence) #Quitar guion bajo
sentence = re.sub(r'@[a-z0-9]+', ' ', sentence) #Quitar menciones
sentence = re.sub(r'\\[n]', ' ', sentence) #Quitar saltos de linea
sentence = re.sub(r'https:\/\/t\.co\/[a-z0-9]{10}', ' ', sentence) #Quitar URLs de este tipo https
sentence = re.sub(r'[^0-9a-z]', ' ', sentence) #Quitar caracteres especiales
sentence = re.sub(r'x[0-9a-z]{2}','',sentence) #Quitar emojis
sentence = re.sub(r'\s+', ' ', sentence) #Quitar espacios extras
sentence = re.sub(r'rt', '', sentence) #Quitar rt
sentence = re.sub(r'\bb\b', '', sentence) #Quitar palabras de una sola letra

sentence
# Out:
e',
#  'i',
#  'miss',
#  'you',
#  'so',
#  'fucken',
#  'much',
#  'ripharambe',
#  '3',
#  'years',
#  'ago',
#  'this',
#  'sweet',
#  'prince',
#  'was',
#  'murdered',
#  'legends',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'let',
#  'us',
#  'win',
#  'today',
#  'for',
#  'our',
#  'boy',
#  'ripharambe',
#  'neverforget',
#  'that',
#  '3',
#  'year',
#  'old',
#  'we',
#  'killed',
#  'harambe',
#  'over',
#  'had',
#  'better',
#  'of',
#  'won',
#  'a',
#  'fucking',
#  'nobel',
#  'prize',
#  'for',
#  'curing',
#  'cancer',
#  'by',
#  'now',
#  'little',
#  'shit',
#  'riph',
#  '3',
#  'years',
#  'since',
#  'harambe',
#  'died',
#  '3',
#  'hr',
#  's',
#  'for',
#  'dietrich',
#  'today',
#  'he',
#  'did',
#  'it',
#  'for',
#  'harambe',
#  'ripharambe',
#  'borntobaseball',
#  'his',
#  'spirit',
#  'lives',
#  'on',
#  'through',
#  'our',
#  'memes',
#  'ripharambe',
#  '3',
#  'years',
#  'ago',
#  'this',
#  'sweet',
#  'prince',
#  'was',
#  'murdered',
#  'legends',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'as',
#  'of',
#  'yesterday',
#  'we',
#  'lost',
#  'a',
#  'wonderful',
#  'member',
#  'to',
#  'the',
#  'ohio',
#  'community',
#  'three',
#  'years',
#  'ago',
#  'the',
#  'man',
#  'we',
#  'lost',
#  'was',
#  'none',
#  'other',
#  'than',
#  'the',
#  'l',
#  'never',
#  'forget',
#  'ripharambe',
#  'it',
#  's',
#  'been',
#  '3',
#  'years',
#  'since',
#  'harambe',
#  'was',
#  'killed',
#  'after',
#  'a',
#  'child',
#  'fell',
#  'into',
#  'his',
#  'enclosure',
#  'he',
#  'deserved',
#  'better',
#  'than',
#  'a',
#  'lifetime',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'a',
#  'legend',
#  'ripharambe',
#  'it',
#  's',
#  'been',
#  '3',
#  'years',
#  'since',
#  'harambe',
#  'was',
#  'killed',
#  'after',
#  'a',
#  'child',
#  'fell',
#  'into',
#  'his',
#  'enclosure',
#  'he',
#  'deserved',
#  'better',
#  'than',
#  'a',
#  'lifetime',
#  'you',
#  'will',
#  'always',
#  'be',
#  'with',
#  'us',
#  'in',
#  'our',
#  'heas',
#  'ripharambe',
#  'as',
#  'of',
#  'yesterday',
#  'we',
#  'lost',
#  'a',
#  'wonderful',
#  'member',
#  'to',
#  'the',
#  'ohio',
#  'community',
#  'three',
#  'years',
#  'ago',
#  'the',
#  'man',
#  'we',
#  'lost',
#  'was',
#  'none',
#  'other',
#  'than',
#  'the',
#  'l',
#  'let',
#  'us',
#  'see',
#  'if',
#  'mueller',
#  'has',
#  'any',
#  'credibility',
#  'left',
#  'harambe',
#  'ripharambe',
#  'noobstruction',
#  'nocollusion',
#  'maga2020',
#  'i',
#  'miss',
#  'you',
#  'so',
#  'fucken',
#  'much',
#  'ripharambe',
#  '3',
#  'years',
#  'ago',
#  'this',
#  'sweet',
#  'prince',
#  'was',
#  'murdered',
#  'legends',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'i',
#  'miss',
#  'you',
#  'so',
#  'fucken',
#  'much',
#  'ripharambe',
#  'good',
#  'clip',
#  'lol',
#  'sorry',
#  'for',
#  'my',
#  'harambe',
#  'noises',
#  'also',
#  'it',
#  'is',
#  'the',
#  'anniversary',
#  'of',
#  'his',
#  'death',
#  'ripharambe',
#  'today',
#  'marks',
#  '3',
#  'years',
#  'ripharambe',
#  'as',
#  'of',
#  'yesterday',
#  'we',
#  'lost',
#  'a',
#  'wonderful',
#  'member',
#  'to',
#  'the',
#  'ohio',
#  'community',
#  'three',
#  'years',
#  'ago',
#  'the',
#  'man',
#  'we',
#  'lost',
#  'was',
#  'none',
#  'other',
#  't',
#  'ripharambe',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'a',
#  'legend',
#  'ripharambe',
#  'i',
#  'miss',
#  'you',
#  'so',
#  'fucken',
#  'much',
#  'ripharambe',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'a',
#  'legend',
#  'ripharambe',
#  'never',
#  'forget',
#  'ripharambe',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'a',
#  'legend',
#  'ripharambe',
#  'no',
#  'one',
#  'know',
#  'who',
#  'you',
#  'are',
#  'till',
#  'your',
#  'dead',
#  'ripharambe',
#  'i',
#  'miss',
#  'you',
#  'so',
#  'fucken',
#  'much',
#  'ripharambe',
#  'daily',
#  'maga',
#  'train',
#  '103',
#  'retweet',
#  'and',
#  'follow',
#  'to',
#  'unite',
#  'patriots',
#  'brands',
#  'in',
#  '2019',
#  'thanks',
#  'ripharambe',
#  'you',
#  'will',
#  'always',
#  'be',
#  'with',
#  'us',
#  'in',
#  'our',
#  'heas',
#  'ripharambe',
#  'rip',
#  'harambe',
#  'good',
#  'lad',
#  'taken',
#  'too',
#  'soon',
#  'ripharambe',
#  'gorillalife',
#  'allharambearewe',
#  'inbielsawetrust',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'a',
#  'legend',
#  'ripharambe',
#  'ripharambe',
#  'gone',
#  'but',
#  'never',
#  'forgotten',
#  'you',
#  'will',
#  'always',
#  'be',
#  'with',
#  'us',
#  'in',
#  'our',
#  'heas',
#  'ripharambe',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'a',
#  'legend',
#  'ripharambe',
#  'we',
#  'lost',
#  'a',
#  'true',
#  'hero',
#  'this',
#  'day',
#  'in',
#  '2016',
#  'dicks',
#  'out',
#  'ripharambe',
#  'his',
#  'spirit',
#  'lives',
#  'on',
#  'through',
#  'our',
#  'memes',
#  'ripharambe',
#  'daily',
#  'maga',
#  'train',
#  '103',
#  'retweet',
#  'and',
#  'follow',
#  'to',
#  'unite',
#  'patriots',
#  'ripharambe',
#  '3',
#  'years',
#  'ago',
#  'this',
#  'sweet',
#  'prince',
#  'was',
#  'murdered',
#  'legends',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'one',
#  'day',
#  'somebody',
#  'will',
#  'say',
#  'your',
#  'name',
#  'for',
#  'the',
#  'last',
#  'time',
#  'today',
#  'is',
#  'not',
#  'that',
#  'day',
#  'ripharambe',
#  'that',
#  '3',
#  'year',
#  'old',
#  'we',
#  'killed',
#  'harambe',
#  'over',
#  'had',
#  'better',
#  'of',
#  'won',
#  'a',
#  'fucking',
#  'nobel',
#  'prize',
#  'for',
#  'curing',
#  'cancer',
#  'by',
#  'now',
#  'little',
#  'shit',
#  'riph',
#  'i',
#  'miss',
#  'you',
#  'so',
#  'fucken',
#  'much',
#  'ripharambe',
#  'i',
#  'miss',
#  'you',
#  'so',
#  'fucken',
#  'much',
#  'ripharambe',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'gonebutnotforgotten',
#  'ripharambe',
#  'it',
#  's',
#  'been',
#  'three',
#  'years',
#  'since',
#  'harambe',
#  'was',
#  'killed',
#  'ripharambe',
#  '2016',
#  'may28',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'a',
#  'legend',
#  'ripharambe',
#  'it',
#  's',
#  'been',
#  '3',
#  'years',
#  'since',
#  'harambe',
#  'was',
#  'killed',
#  'after',
#  'a',
#  'child',
#  'fell',
#  'into',
#  'his',
#  'enclosure',
#  'he',
#  'deserved',
#  'better',
#  'than',
#  'a',
#  'lifetime',
#  'the',
#  'streets',
#  'will',
#  'never',
#  'forget',
#  'ripharambe',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'a',
#  'legend',
#  'ripharambe',
#  'three',
#  'years',
#  'ago',
#  'to',
#  'this',
#  'day',
#  'we',
#  'lost',
#  'a',
#  'true',
#  'king',
#  'harambe',
#  'ripharambe',
#  '3',
#  'years',
#  'ago',
#  'this',
#  'sweet',
#  'prince',
#  'was',
#  'murdered',
#  'legends',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'i',
#  'miss',
#  'you',
#  'so',
#  'fucken',
#  'much',
#  'ripharambe',
#  'it',
#  'still',
#  'doesn',
#  't',
#  'feel',
#  'real',
#  'rest',
#  'easy',
#  'sweet',
#  'prince',
#  'ripharambe',
#  'ripharambe',
#  'we',
#  'lost',
#  'a',
#  'true',
#  'hero',
#  'this',
#  'day',
#  'in',
#  '2016',
#  'dicks',
#  'out',
#  'ripharambe',
#  'one',
#  'day',
#  'somebody',
#  'will',
#  'say',
#  'your',
#  'name',
#  'for',
#  'the',
#  'last',
#  'time',
#  'today',
#  'is',
#  'not',
#  'that',
#  'day',
#  'ripharambe',
#  '3',
#  'years',
#  'ago',
#  'seems',
#  'like',
#  'it',
#  'was',
#  'yesterday',
#  'neverforget',
#  'ripharambe',
#  '3',
#  'years',
#  'ago',
#  'this',
#  'sweet',
#  'prince',
#  'was',
#  'murdered',
#  'legends',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'can',
#  'not',
#  'believe',
#  'it',
#  'is',
#  'been',
#  '3',
#  'years',
#  'already',
#  'ripharambe',
#  'his',
#  'spirit',
#  'lives',
#  'on',
#  'through',
#  'our',
#  'memes',
#  'ripharambe',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'a',
#  'legend',
#  'ripharambe',
#  '3',
#  'years',
#  'ago',
#  'today',
#  'nothing',
#  'but',
#  'respect',
#  'to',
#  'the',
#  'king',
#  'ripharambe',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'a',
#  'legend',
#  'ripharambe',
#  '3',
#  'years',
#  'ago',
#  'this',
#  'sweet',
#  'prince',
#  'was',
#  'murdered',
#  'legends',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'i',
#  'miss',
#  'you',
#  'so',
#  'fucken',
#  'much',
#  'ripharambe',
#  'it',
#  'still',
#  'doesn',
#  't',
#  'feel',
#  'real',
#  'rest',
#  'easy',
#  'sweet',
#  'prince',
#  'ripharambe',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'a',
#  'legend',
#  'ripharambe',
#  'wish',
#  'we',
#  'could',
#  'go',
#  'back',
#  'in',
#  'time',
#  'and',
#  'save',
#  'harambe',
#  'ripharambe',
#  'i',
#  'miss',
#  'you',
#  'so',
#  'fucken',
#  'much',
#  'ripharambe',
#  'gone',
#  'but',
#  'never',
#  'forgotten',
#  'ripharambe',
#  'harambesaves',
#  'derangeddonald',
#  'traitorump',
#  'ripharambe',
#  'putinsgop',
#  'cheaterump',
#  'that',
#  '3',
#  'year',
#  'old',
#  'we',
#  'killed',
#  'harambe',
#  'over',
#  'had',
#  'better',
#  'of',
#  'won',
#  'a',
#  'fucking',
#  'nobel',
#  'prize',
#  'for',
#  'curing',
#  'cancer',
#  'by',
#  'now',
#  'little',
#  'shit',
#  'riph',
#  'derangeddonald',
#  'traitorump',
#  'ripharambe',
#  'putinsgop',
#  'cheaterump',
#  'donthecon',
#  'i',
#  'miss',
#  'you',
#  'so',
#  'fucken',
#  'much',
#  'ripharambe',
#  'rest',
#  'in',
#  'peace',
#  'bro',
#  'ripharambe',
#  'derangeddonald',
#  'traitorump',
#  'ripharambe',
#  'putinsgop',
#  'cheaterump',
#  'donthecon',
#  'his',
#  'spirit',
#  'lives',
#  'on',
#  'through',
#  'our',
#  'memes',
#  'ripharambe',
#  'derangeddonald',
#  'traitorump',
#  'ripharambe',
#  'putinsgop',
#  'cheaterump',
#  'donthecon',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'a',
#  'legend',
#  'ripharambe',
#  'beautiful',
#  'harambe',
#  'tribute',
#  'guys',
#  'even',
#  'if',
#  'it',
#  'is',
#  'a',
#  'day',
#  'late',
#  'i',
#  'have',
#  'tears',
#  'of',
#  'laughter',
#  'in',
#  'my',
#  'eyes',
#  'ripharambe',
#  'we',
#  'lost',
#  'a',
#  'true',
#  'hero',
#  'this',
#  'day',
#  'in',
#  '2016',
#  'dicks',
#  'out',
#  'ripharambe',
#  'ripharambe',
#  '3',
#  'years',
#  'later',
#  'ripharambe',
#  '3',
#  'years',
#  'ago',
#  'this',
#  'sweet',
#  'prince',
#  'was',
#  'murdered',
#  'legends',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'beautiful',
#  'harambe',
#  'tribute',
#  'guys',
#  'even',
#  'if',
#  'it',
#  'is',
#  'a',
#  'day',
#  'late',
#  'i',
#  'have',
#  'tears',
#  'of',
#  'laughter',
#  'in',
#  'my',
#  'eyes',
#  'ripharambe',
#  'i',
#  'miss',
#  'you',
#  'so',
#  'fucken',
#  'much',
#  'ripharambe',
#  'ripharambe',
#  'never',
#  'forget',
#  '3',
#  'years',
#  'ago',
#  'seems',
#  'like',
#  'it',
#  'was',
#  'yesterday',
#  'neverforget',
#  'ripharambe',
#  'ripharambe',
#  'his',
#  'spirit',
#  'lives',
#  'on',
#  'through',
#  'our',
#  'memes',
#  'ripharambe',
#  'it',
#  's',
#  'been',
#  '3',
#  'years',
#  'since',
#  'harambe',
#  'was',
#  'killed',
#  'after',
#  'a',
#  'child',
#  'fell',
#  'into',
#  'his',
#  'enclosure',
#  'he',
#  'deserved',
#  'better',
#  'than',
#  'a',
#  'lifetime',
#  'his',
#  'spirit',
#  'lives',
#  'on',
#  'through',
#  'our',
#  'memes',
#  ...]

# %%
sentence_no_stopwords = [token for token in sentence_tokenized if token not in stopwords_en]
sentence_no_stopwords
# Out:
# ['3',
#  'long',
#  'years',
#  'ripharambe',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  '3',
#  'years',
#  'ago',
#  'sweet',
#  'prince',
#  'murdered',
#  'legends',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'let',
#  'us',
#  'win',
#  'today',
#  'boy',
#  'ripharambe',
#  'neverforget',
#  '3',
#  'year',
#  'old',
#  'killed',
#  'harambe',
#  'better',
#  'fucking',
#  'nobel',
#  'prize',
#  'curing',
#  'cancer',
#  'little',
#  'shit',
#  'riph',
#  '3',
#  'years',
#  'since',
#  'harambe',
#  'died',
#  '3',
#  'hr',
#  'dietrich',
#  'today',
#  'harambe',
#  'ripharambe',
#  'borntobaseball',
#  'spirit',
#  'lives',
#  'memes',
#  'ripharambe',
#  '3',
#  'years',
#  'ago',
#  'sweet',
#  'prince',
#  'murdered',
#  'legends',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'yesterday',
#  'lost',
#  'wonderful',
#  'member',
#  'ohio',
#  'community',
#  'three',
#  'years',
#  'ago',
#  'man',
#  'lost',
#  'none',
#  'l',
#  'never',
#  'forget',
#  'ripharambe',
#  '3',
#  'years',
#  'since',
#  'harambe',
#  'killed',
#  'child',
#  'fell',
#  'enclosure',
#  'deserved',
#  'better',
#  'lifetime',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  '3',
#  'years',
#  'since',
#  'harambe',
#  'killed',
#  'child',
#  'fell',
#  'enclosure',
#  'deserved',
#  'better',
#  'lifetime',
#  'always',
#  'us',
#  'heas',
#  'ripharambe',
#  'yesterday',
#  'lost',
#  'wonderful',
#  'member',
#  'ohio',
#  'community',
#  'three',
#  'years',
#  'ago',
#  'man',
#  'lost',
#  'none',
#  'l',
#  'let',
#  'us',
#  'see',
#  'mueller',
#  'credibility',
#  'left',
#  'harambe',
#  'ripharambe',
#  'noobstruction',
#  'nocollusion',
#  'maga2020',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  '3',
#  'years',
#  'ago',
#  'sweet',
#  'prince',
#  'murdered',
#  'legends',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  'good',
#  'clip',
#  'lol',
#  'sorry',
#  'harambe',
#  'noises',
#  'also',
#  'anniversary',
#  'death',
#  'ripharambe',
#  'today',
#  'marks',
#  '3',
#  'years',
#  'ripharambe',
#  'yesterday',
#  'lost',
#  'wonderful',
#  'member',
#  'ohio',
#  'community',
#  'three',
#  'years',
#  'ago',
#  'man',
#  'lost',
#  'none',
#  'ripharambe',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  'never',
#  'forget',
#  'ripharambe',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  'one',
#  'know',
#  'till',
#  'dead',
#  'ripharambe',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  'daily',
#  'maga',
#  'train',
#  '103',
#  'retweet',
#  'follow',
#  'unite',
#  'patriots',
#  'brands',
#  '2019',
#  'thanks',
#  'ripharambe',
#  'always',
#  'us',
#  'heas',
#  'ripharambe',
#  'rip',
#  'harambe',
#  'good',
#  'lad',
#  'taken',
#  'soon',
#  'ripharambe',
#  'gorillalife',
#  'allharambearewe',
#  'inbielsawetrust',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  'ripharambe',
#  'gone',
#  'never',
#  'forgotten',
#  'always',
#  'us',
#  'heas',
#  'ripharambe',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  'lost',
#  'true',
#  'hero',
#  'day',
#  '2016',
#  'dicks',
#  'ripharambe',
#  'spirit',
#  'lives',
#  'memes',
#  'ripharambe',
#  'daily',
#  'maga',
#  'train',
#  '103',
#  'retweet',
#  'follow',
#  'unite',
#  'patriots',
#  'ripharambe',
#  '3',
#  'years',
#  'ago',
#  'sweet',
#  'prince',
#  'murdered',
#  'legends',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'one',
#  'day',
#  'somebody',
#  'say',
#  'name',
#  'last',
#  'time',
#  'today',
#  'day',
#  'ripharambe',
#  '3',
#  'year',
#  'old',
#  'killed',
#  'harambe',
#  'better',
#  'fucking',
#  'nobel',
#  'prize',
#  'curing',
#  'cancer',
#  'little',
#  'shit',
#  'riph',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'gonebutnotforgotten',
#  'ripharambe',
#  'three',
#  'years',
#  'since',
#  'harambe',
#  'killed',
#  'ripharambe',
#  '2016',
#  'may28',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  '3',
#  'years',
#  'since',
#  'harambe',
#  'killed',
#  'child',
#  'fell',
#  'enclosure',
#  'deserved',
#  'better',
#  'lifetime',
#  'streets',
#  'never',
#  'forget',
#  'ripharambe',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  'three',
#  'years',
#  'ago',
#  'day',
#  'lost',
#  'true',
#  'king',
#  'harambe',
#  'ripharambe',
#  '3',
#  'years',
#  'ago',
#  'sweet',
#  'prince',
#  'murdered',
#  'legends',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  'still',
#  'feel',
#  'real',
#  'rest',
#  'easy',
#  'sweet',
#  'prince',
#  'ripharambe',
#  'ripharambe',
#  'lost',
#  'true',
#  'hero',
#  'day',
#  '2016',
#  'dicks',
#  'ripharambe',
#  'one',
#  'day',
#  'somebody',
#  'say',
#  'name',
#  'last',
#  'time',
#  'today',
#  'day',
#  'ripharambe',
#  '3',
#  'years',
#  'ago',
#  'seems',
#  'like',
#  'yesterday',
#  'neverforget',
#  'ripharambe',
#  '3',
#  'years',
#  'ago',
#  'sweet',
#  'prince',
#  'murdered',
#  'legends',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'believe',
#  '3',
#  'years',
#  'already',
#  'ripharambe',
#  'spirit',
#  'lives',
#  'memes',
#  'ripharambe',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  '3',
#  'years',
#  'ago',
#  'today',
#  'nothing',
#  'respect',
#  'king',
#  'ripharambe',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  '3',
#  'years',
#  'ago',
#  'sweet',
#  'prince',
#  'murdered',
#  'legends',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  'still',
#  'feel',
#  'real',
#  'rest',
#  'easy',
#  'sweet',
#  'prince',
#  'ripharambe',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  'wish',
#  'could',
#  'go',
#  'back',
#  'time',
#  'save',
#  'harambe',
#  'ripharambe',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  'gone',
#  'never',
#  'forgotten',
#  'ripharambe',
#  'harambesaves',
#  'derangeddonald',
#  'traitorump',
#  'ripharambe',
#  'putinsgop',
#  'cheaterump',
#  '3',
#  'year',
#  'old',
#  'killed',
#  'harambe',
#  'better',
#  'fucking',
#  'nobel',
#  'prize',
#  'curing',
#  'cancer',
#  'little',
#  'shit',
#  'riph',
#  'derangeddonald',
#  'traitorump',
#  'ripharambe',
#  'putinsgop',
#  'cheaterump',
#  'donthecon',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  'rest',
#  'peace',
#  'bro',
#  'ripharambe',
#  'derangeddonald',
#  'traitorump',
#  'ripharambe',
#  'putinsgop',
#  'cheaterump',
#  'donthecon',
#  'spirit',
#  'lives',
#  'memes',
#  'ripharambe',
#  'derangeddonald',
#  'traitorump',
#  'ripharambe',
#  'putinsgop',
#  'cheaterump',
#  'donthecon',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  'beautiful',
#  'harambe',
#  'tribute',
#  'guys',
#  'even',
#  'day',
#  'late',
#  'tears',
#  'laughter',
#  'eyes',
#  'ripharambe',
#  'lost',
#  'true',
#  'hero',
#  'day',
#  '2016',
#  'dicks',
#  'ripharambe',
#  'ripharambe',
#  '3',
#  'years',
#  'later',
#  'ripharambe',
#  '3',
#  'years',
#  'ago',
#  'sweet',
#  'prince',
#  'murdered',
#  'legends',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'beautiful',
#  'harambe',
#  'tribute',
#  'guys',
#  'even',
#  'day',
#  'late',
#  'tears',
#  'laughter',
#  'eyes',
#  'ripharambe',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  'ripharambe',
#  'never',
#  'forget',
#  '3',
#  'years',
#  'ago',
#  'seems',
#  'like',
#  'yesterday',
#  'neverforget',
#  'ripharambe',
#  'ripharambe',
#  'spirit',
#  'lives',
#  'memes',
#  'ripharambe',
#  '3',
#  'years',
#  'since',
#  'harambe',
#  'killed',
#  'child',
#  'fell',
#  'enclosure',
#  'deserved',
#  'better',
#  'lifetime',
#  'spirit',
#  'lives',
#  'memes',
#  'ripharambe',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  '3',
#  'years',
#  'ago',
#  'sweet',
#  'prince',
#  'murdered',
#  'legends',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  '3',
#  'year',
#  'old',
#  'killed',
#  'harambe',
#  'better',
#  'fucking',
#  'nobel',
#  'prize',
#  'curing',
#  'cancer',
#  'little',
#  'shit',
#  'riph',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  'sad',
#  'day',
#  '3',
#  'years',
#  'ago',
#  'today',
#  'lost',
#  'harambe',
#  'ripharambe',
#  '3',
#  'years',
#  'ago',
#  'sweet',
#  'prince',
#  'murdered',
#  'legends',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'spirit',
#  'lives',
#  'memes',
#  'ripharambe',
#  '3',
#  'years',
#  'since',
#  'harambe',
#  'died',
#  '3',
#  'hr',
#  'dietrich',
#  'today',
#  'harambe',
#  'ripharambe',
#  'borntobaseball',
#  '3',
#  'years',
#  'ago',
#  'today',
#  'ripharambe',
#  'ripharambe',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  'thank',
#  'everyone',
#  'paicipated',
#  'first',
#  'charity',
#  'telethon',
#  'tonight',
#  'youtube',
#  'channel',
#  'together',
#  'raised',
#  'spirit',
#  'lives',
#  'memes',
#  'ripharambe',
#  'ripharambe',
#  'sorely',
#  'missed',
#  'lives',
#  'heas',
#  'ripharambe',
#  'today',
#  'masks',
#  '3',
#  'year',
#  'anniversary',
#  'assassination',
#  'cincinnati',
#  'zoo',
#  'harambe',
#  'great',
#  'remembe',
#  '3',
#  'years',
#  'ago',
#  'sweet',
#  'prince',
#  'murdered',
#  'legends',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  '3',
#  'years',
#  'ago',
#  'sweet',
#  'prince',
#  'murdered',
#  'legends',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  '3',
#  'years',
#  'since',
#  'harambe',
#  'killed',
#  'child',
#  'fell',
#  'enclosure',
#  'deserved',
#  'better',
#  'lifetime',
#  'new',
#  'law',
#  'everyone',
#  'pay',
#  'respects',
#  'fallen',
#  'hero',
#  'harambe',
#  'jailed',
#  'one',
#  'year',
#  'l',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  '3',
#  'year',
#  'old',
#  'killed',
#  'harambe',
#  'better',
#  'fucking',
#  'nobel',
#  'prize',
#  'curing',
#  'cancer',
#  'little',
#  'shit',
#  'riph',
#  '3',
#  'years',
#  'ago',
#  'sweet',
#  'prince',
#  'murdered',
#  'legends',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'kakek',
#  'ini',
#  'berharap',
#  'naik',
#  'haji',
#  'ya',
#  'allah',
#  'karuniakan',
#  'kepada',
#  'kami',
#  'rezeki',
#  'untuk',
#  'mengunjungi',
#  'rumah',
#  'mu',
#  'yang',
#  'agung',
#  'dan',
#  'rasul',
#  'ripharambe',
#  'today',
#  'day',
#  'retweet',
#  'ripharambe',
#  'ay',
#  'yo',
#  'almost',
#  'forgot',
#  'roll',
#  'peace',
#  'homie',
#  'harambe',
#  'really',
#  'miss',
#  'dawg',
#  'ripharambe',
#  'neva',
#  'forget',
#  '3',
#  'years',
#  'ago',
#  'sweet',
#  'prince',
#  'murdered',
#  'legends',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'still',
#  'feel',
#  'real',
#  'rest',
#  'easy',
#  'sweet',
#  'prince',
#  'ripharambe',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  '3',
#  'years',
#  'ago',
#  'today',
#  'harambe',
#  'taken',
#  'us',
#  'soon',
#  'rip',
#  'peace',
#  'sweet',
#  'prince',
#  'ripharambe',
#  'felt',
#  'little',
#  'today',
#  'makes',
#  'sense',
#  'ripharambe',
#  'something',
#  'impoant',
#  'ripharambe',
#  'youtube',
#  'ballet',
#  'thankyou',
#  'took',
#  'picture',
#  '3',
#  'years',
#  'ago',
#  'day',
#  'goes',
#  'think',
#  'ripharambe',
#  'three',
#  'years',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  'ripharambe',
#  'gone',
#  'never',
#  ...]

# %%
final = [lemmatizer.lemmatize(token) for token in sentence_no_stopwords]
final
# Out:
# ['3',
#  'long',
#  'year',
#  'ripharambe',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  '3',
#  'year',
#  'ago',
#  'sweet',
#  'prince',
#  'murdered',
#  'legend',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'let',
#  'u',
#  'win',
#  'today',
#  'boy',
#  'ripharambe',
#  'neverforget',
#  '3',
#  'year',
#  'old',
#  'killed',
#  'harambe',
#  'better',
#  'fucking',
#  'nobel',
#  'prize',
#  'curing',
#  'cancer',
#  'little',
#  'shit',
#  'riph',
#  '3',
#  'year',
#  'since',
#  'harambe',
#  'died',
#  '3',
#  'hr',
#  'dietrich',
#  'today',
#  'harambe',
#  'ripharambe',
#  'borntobaseball',
#  'spirit',
#  'life',
#  'meme',
#  'ripharambe',
#  '3',
#  'year',
#  'ago',
#  'sweet',
#  'prince',
#  'murdered',
#  'legend',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'yesterday',
#  'lost',
#  'wonderful',
#  'member',
#  'ohio',
#  'community',
#  'three',
#  'year',
#  'ago',
#  'man',
#  'lost',
#  'none',
#  'l',
#  'never',
#  'forget',
#  'ripharambe',
#  '3',
#  'year',
#  'since',
#  'harambe',
#  'killed',
#  'child',
#  'fell',
#  'enclosure',
#  'deserved',
#  'better',
#  'lifetime',
#  'three',
#  'year',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  '3',
#  'year',
#  'since',
#  'harambe',
#  'killed',
#  'child',
#  'fell',
#  'enclosure',
#  'deserved',
#  'better',
#  'lifetime',
#  'always',
#  'u',
#  'heas',
#  'ripharambe',
#  'yesterday',
#  'lost',
#  'wonderful',
#  'member',
#  'ohio',
#  'community',
#  'three',
#  'year',
#  'ago',
#  'man',
#  'lost',
#  'none',
#  'l',
#  'let',
#  'u',
#  'see',
#  'mueller',
#  'credibility',
#  'left',
#  'harambe',
#  'ripharambe',
#  'noobstruction',
#  'nocollusion',
#  'maga2020',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  '3',
#  'year',
#  'ago',
#  'sweet',
#  'prince',
#  'murdered',
#  'legend',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  'good',
#  'clip',
#  'lol',
#  'sorry',
#  'harambe',
#  'noise',
#  'also',
#  'anniversary',
#  'death',
#  'ripharambe',
#  'today',
#  'mark',
#  '3',
#  'year',
#  'ripharambe',
#  'yesterday',
#  'lost',
#  'wonderful',
#  'member',
#  'ohio',
#  'community',
#  'three',
#  'year',
#  'ago',
#  'man',
#  'lost',
#  'none',
#  'ripharambe',
#  'three',
#  'year',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  'three',
#  'year',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  'never',
#  'forget',
#  'ripharambe',
#  'three',
#  'year',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  'one',
#  'know',
#  'till',
#  'dead',
#  'ripharambe',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  'daily',
#  'maga',
#  'train',
#  '103',
#  'retweet',
#  'follow',
#  'unite',
#  'patriot',
#  'brand',
#  '2019',
#  'thanks',
#  'ripharambe',
#  'always',
#  'u',
#  'heas',
#  'ripharambe',
#  'rip',
#  'harambe',
#  'good',
#  'lad',
#  'taken',
#  'soon',
#  'ripharambe',
#  'gorillalife',
#  'allharambearewe',
#  'inbielsawetrust',
#  'three',
#  'year',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  'ripharambe',
#  'gone',
#  'never',
#  'forgotten',
#  'always',
#  'u',
#  'heas',
#  'ripharambe',
#  'three',
#  'year',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  'lost',
#  'true',
#  'hero',
#  'day',
#  '2016',
#  'dick',
#  'ripharambe',
#  'spirit',
#  'life',
#  'meme',
#  'ripharambe',
#  'daily',
#  'maga',
#  'train',
#  '103',
#  'retweet',
#  'follow',
#  'unite',
#  'patriot',
#  'ripharambe',
#  '3',
#  'year',
#  'ago',
#  'sweet',
#  'prince',
#  'murdered',
#  'legend',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'one',
#  'day',
#  'somebody',
#  'say',
#  'name',
#  'last',
#  'time',
#  'today',
#  'day',
#  'ripharambe',
#  '3',
#  'year',
#  'old',
#  'killed',
#  'harambe',
#  'better',
#  'fucking',
#  'nobel',
#  'prize',
#  'curing',
#  'cancer',
#  'little',
#  'shit',
#  'riph',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  'three',
#  'year',
#  'ago',
#  'today',
#  'gonebutnotforgotten',
#  'ripharambe',
#  'three',
#  'year',
#  'since',
#  'harambe',
#  'killed',
#  'ripharambe',
#  '2016',
#  'may28',
#  'three',
#  'year',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  '3',
#  'year',
#  'since',
#  'harambe',
#  'killed',
#  'child',
#  'fell',
#  'enclosure',
#  'deserved',
#  'better',
#  'lifetime',
#  'street',
#  'never',
#  'forget',
#  'ripharambe',
#  'three',
#  'year',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  'three',
#  'year',
#  'ago',
#  'day',
#  'lost',
#  'true',
#  'king',
#  'harambe',
#  'ripharambe',
#  '3',
#  'year',
#  'ago',
#  'sweet',
#  'prince',
#  'murdered',
#  'legend',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  'still',
#  'feel',
#  'real',
#  'rest',
#  'easy',
#  'sweet',
#  'prince',
#  'ripharambe',
#  'ripharambe',
#  'lost',
#  'true',
#  'hero',
#  'day',
#  '2016',
#  'dick',
#  'ripharambe',
#  'one',
#  'day',
#  'somebody',
#  'say',
#  'name',
#  'last',
#  'time',
#  'today',
#  'day',
#  'ripharambe',
#  '3',
#  'year',
#  'ago',
#  'seems',
#  'like',
#  'yesterday',
#  'neverforget',
#  'ripharambe',
#  '3',
#  'year',
#  'ago',
#  'sweet',
#  'prince',
#  'murdered',
#  'legend',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'believe',
#  '3',
#  'year',
#  'already',
#  'ripharambe',
#  'spirit',
#  'life',
#  'meme',
#  'ripharambe',
#  'three',
#  'year',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  '3',
#  'year',
#  'ago',
#  'today',
#  'nothing',
#  'respect',
#  'king',
#  'ripharambe',
#  'three',
#  'year',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  '3',
#  'year',
#  'ago',
#  'sweet',
#  'prince',
#  'murdered',
#  'legend',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  'still',
#  'feel',
#  'real',
#  'rest',
#  'easy',
#  'sweet',
#  'prince',
#  'ripharambe',
#  'three',
#  'year',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  'wish',
#  'could',
#  'go',
#  'back',
#  'time',
#  'save',
#  'harambe',
#  'ripharambe',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  'gone',
#  'never',
#  'forgotten',
#  'ripharambe',
#  'harambesaves',
#  'derangeddonald',
#  'traitorump',
#  'ripharambe',
#  'putinsgop',
#  'cheaterump',
#  '3',
#  'year',
#  'old',
#  'killed',
#  'harambe',
#  'better',
#  'fucking',
#  'nobel',
#  'prize',
#  'curing',
#  'cancer',
#  'little',
#  'shit',
#  'riph',
#  'derangeddonald',
#  'traitorump',
#  'ripharambe',
#  'putinsgop',
#  'cheaterump',
#  'donthecon',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  'rest',
#  'peace',
#  'bro',
#  'ripharambe',
#  'derangeddonald',
#  'traitorump',
#  'ripharambe',
#  'putinsgop',
#  'cheaterump',
#  'donthecon',
#  'spirit',
#  'life',
#  'meme',
#  'ripharambe',
#  'derangeddonald',
#  'traitorump',
#  'ripharambe',
#  'putinsgop',
#  'cheaterump',
#  'donthecon',
#  'three',
#  'year',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  'beautiful',
#  'harambe',
#  'tribute',
#  'guy',
#  'even',
#  'day',
#  'late',
#  'tear',
#  'laughter',
#  'eye',
#  'ripharambe',
#  'lost',
#  'true',
#  'hero',
#  'day',
#  '2016',
#  'dick',
#  'ripharambe',
#  'ripharambe',
#  '3',
#  'year',
#  'later',
#  'ripharambe',
#  '3',
#  'year',
#  'ago',
#  'sweet',
#  'prince',
#  'murdered',
#  'legend',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'beautiful',
#  'harambe',
#  'tribute',
#  'guy',
#  'even',
#  'day',
#  'late',
#  'tear',
#  'laughter',
#  'eye',
#  'ripharambe',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  'ripharambe',
#  'never',
#  'forget',
#  '3',
#  'year',
#  'ago',
#  'seems',
#  'like',
#  'yesterday',
#  'neverforget',
#  'ripharambe',
#  'ripharambe',
#  'spirit',
#  'life',
#  'meme',
#  'ripharambe',
#  '3',
#  'year',
#  'since',
#  'harambe',
#  'killed',
#  'child',
#  'fell',
#  'enclosure',
#  'deserved',
#  'better',
#  'lifetime',
#  'spirit',
#  'life',
#  'meme',
#  'ripharambe',
#  'three',
#  'year',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  'three',
#  'year',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  '3',
#  'year',
#  'ago',
#  'sweet',
#  'prince',
#  'murdered',
#  'legend',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'three',
#  'year',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  '3',
#  'year',
#  'old',
#  'killed',
#  'harambe',
#  'better',
#  'fucking',
#  'nobel',
#  'prize',
#  'curing',
#  'cancer',
#  'little',
#  'shit',
#  'riph',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  'sad',
#  'day',
#  '3',
#  'year',
#  'ago',
#  'today',
#  'lost',
#  'harambe',
#  'ripharambe',
#  '3',
#  'year',
#  'ago',
#  'sweet',
#  'prince',
#  'murdered',
#  'legend',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'spirit',
#  'life',
#  'meme',
#  'ripharambe',
#  '3',
#  'year',
#  'since',
#  'harambe',
#  'died',
#  '3',
#  'hr',
#  'dietrich',
#  'today',
#  'harambe',
#  'ripharambe',
#  'borntobaseball',
#  '3',
#  'year',
#  'ago',
#  'today',
#  'ripharambe',
#  'ripharambe',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  'thank',
#  'everyone',
#  'paicipated',
#  'first',
#  'charity',
#  'telethon',
#  'tonight',
#  'youtube',
#  'channel',
#  'together',
#  'raised',
#  'spirit',
#  'life',
#  'meme',
#  'ripharambe',
#  'ripharambe',
#  'sorely',
#  'missed',
#  'life',
#  'heas',
#  'ripharambe',
#  'today',
#  'mask',
#  '3',
#  'year',
#  'anniversary',
#  'assassination',
#  'cincinnati',
#  'zoo',
#  'harambe',
#  'great',
#  'remembe',
#  '3',
#  'year',
#  'ago',
#  'sweet',
#  'prince',
#  'murdered',
#  'legend',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  '3',
#  'year',
#  'ago',
#  'sweet',
#  'prince',
#  'murdered',
#  'legend',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  '3',
#  'year',
#  'since',
#  'harambe',
#  'killed',
#  'child',
#  'fell',
#  'enclosure',
#  'deserved',
#  'better',
#  'lifetime',
#  'new',
#  'law',
#  'everyone',
#  'pay',
#  'respect',
#  'fallen',
#  'hero',
#  'harambe',
#  'jailed',
#  'one',
#  'year',
#  'l',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  '3',
#  'year',
#  'old',
#  'killed',
#  'harambe',
#  'better',
#  'fucking',
#  'nobel',
#  'prize',
#  'curing',
#  'cancer',
#  'little',
#  'shit',
#  'riph',
#  '3',
#  'year',
#  'ago',
#  'sweet',
#  'prince',
#  'murdered',
#  'legend',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'kakek',
#  'ini',
#  'berharap',
#  'naik',
#  'haji',
#  'ya',
#  'allah',
#  'karuniakan',
#  'kepada',
#  'kami',
#  'rezeki',
#  'untuk',
#  'mengunjungi',
#  'rumah',
#  'mu',
#  'yang',
#  'agung',
#  'dan',
#  'rasul',
#  'ripharambe',
#  'today',
#  'day',
#  'retweet',
#  'ripharambe',
#  'ay',
#  'yo',
#  'almost',
#  'forgot',
#  'roll',
#  'peace',
#  'homie',
#  'harambe',
#  'really',
#  'miss',
#  'dawg',
#  'ripharambe',
#  'neva',
#  'forget',
#  '3',
#  'year',
#  'ago',
#  'sweet',
#  'prince',
#  'murdered',
#  'legend',
#  'never',
#  'die',
#  'ripharambe',
#  'harambe',
#  'still',
#  'feel',
#  'real',
#  'rest',
#  'easy',
#  'sweet',
#  'prince',
#  'ripharambe',
#  'three',
#  'year',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  'miss',
#  'fucken',
#  'much',
#  'ripharambe',
#  '3',
#  'year',
#  'ago',
#  'today',
#  'harambe',
#  'taken',
#  'u',
#  'soon',
#  'rip',
#  'peace',
#  'sweet',
#  'prince',
#  'ripharambe',
#  'felt',
#  'little',
#  'today',
#  'make',
#  'sense',
#  'ripharambe',
#  'something',
#  'impoant',
#  'ripharambe',
#  'youtube',
#  'ballet',
#  'thankyou',
#  'took',
#  'picture',
#  '3',
#  'year',
#  'ago',
#  'day',
#  'go',
#  'think',
#  'ripharambe',
#  'three',
#  'year',
#  'ago',
#  'today',
#  'cincinnati',
#  'lost',
#  'legend',
#  'ripharambe',
#  'ripharambe',
#  'gone',
#  'never',
#  ...]

# %%
final = ' '.join(final)
final
# Out:
# '3 long year ripharambe miss fucken much ripharambe 3 year ago sweet prince murdered legend never die ripharambe haramb